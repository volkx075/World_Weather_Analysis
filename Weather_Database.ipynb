# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
# print(city_url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | olinda
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | san patricio
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | kalemie
# Processing Record 19 of Set 1 | coahuayana
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | turan
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | isla vista
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | mandal
# Processing Record 29 of Set 1 | russkaya polyana
# Processing Record 30 of Set 1 | korla
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | mwene-ditu
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | kaeo
# Processing Record 37 of Set 1 | hamilton
# Processing Record 38 of Set 1 | ryotsu
# Processing Record 39 of Set 1 | kalia
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | harer
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | hay river
# Processing Record 45 of Set 1 | cam ranh
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | los llanos de aridane
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | puerto escondido
# Processing Record 50 of Set 1 | payakumbuh
# Processing Record 1 of Set 2 | isangel
# Processing Record 2 of Set 2 | senneterre
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | kiama
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | prado
# Processing Record 8 of Set 2 | americus
# Processing Record 9 of Set 2 | hasanabad
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | reading
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | cockburn town
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | gao
# Processing Record 18 of Set 2 | san cristobal
# Processing Record 19 of Set 2 | maldonado
# Processing Record 20 of Set 2 | nanakuli
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | fortuna
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | aswan
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 2 | north bend
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | berlevag
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | grimshaw
# Processing Record 36 of Set 2 | harnosand
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | shimizu
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | aksarka
# Processing Record 41 of Set 2 | tarakan
# Processing Record 42 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 2 | tahta
# Processing Record 44 of Set 2 | college
# Processing Record 45 of Set 2 | paamiut
# Processing Record 46 of Set 2 | metro
# Processing Record 47 of Set 2 | havre-saint-pierre
# Processing Record 48 of Set 2 | suez
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | lima
# Processing Record 2 of Set 3 | sur
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | preobrazheniye
# Processing Record 5 of Set 3 | altay
# Processing Record 6 of Set 3 | arlit
# Processing Record 7 of Set 3 | tateyama
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | andenes
# Processing Record 10 of Set 3 | hervey bay
# Processing Record 11 of Set 3 | coihaique
# Processing Record 12 of Set 3 | port augusta
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | boguchany
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | pangoa
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | seguela
# Processing Record 23 of Set 3 | kavaratti
# Processing Record 24 of Set 3 | port lincoln
# Processing Record 25 of Set 3 | grindavik
# Processing Record 26 of Set 3 | tayga
# Processing Record 27 of Set 3 | santo domingo de guzman
# Processing Record 28 of Set 3 | san vicente
# Processing Record 29 of Set 3 | sabang
# Processing Record 30 of Set 3 | verkhnevilyuysk
# Processing Record 31 of Set 3 | ulcinj
# Processing Record 32 of Set 3 | richards bay
# Processing Record 33 of Set 3 | komsomolskiy
# Processing Record 34 of Set 3 | borba
# Processing Record 35 of Set 3 | ashtabula
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | maningrida
# Processing Record 38 of Set 3 | port lavaca
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | kovur
# Processing Record 41 of Set 3 | flin flon
# Processing Record 42 of Set 3 | keokuk
# Processing Record 43 of Set 3 | raudeberg
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | ampanihy
# Processing Record 46 of Set 3 | sorland
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | alice springs
# Processing Record 49 of Set 3 | takoradi
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | tairua
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | udachnyy
# Processing Record 5 of Set 4 | togur
# Processing Record 6 of Set 4 | farafangana
# Processing Record 7 of Set 4 | obo
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | iqaluit
# Processing Record 10 of Set 4 | plettenberg bay
# Processing Record 11 of Set 4 | hailar
# Processing Record 12 of Set 4 | zhezkazgan
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | salym
# Processing Record 15 of Set 4 | lepaera
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | mozarlandia
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | iguape
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | olafsvik
# Processing Record 23 of Set 4 | voznesenskoye
# Processing Record 24 of Set 4 | axim
# Processing Record 25 of Set 4 | dudinka
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | pearl river
# Processing Record 28 of Set 4 | gizo
# Processing Record 29 of Set 4 | avera
# Processing Record 30 of Set 4 | lata
# Processing Record 31 of Set 4 | hami
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | seryshevo
# Processing Record 34 of Set 4 | new norfolk
# Processing Record 35 of Set 4 | taoudenni
# Processing Record 36 of Set 4 | east london
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | kholmogory
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | half moon bay
# Processing Record 41 of Set 4 | rudnogorsk
# Processing Record 42 of Set 4 | chifeng
# Processing Record 43 of Set 4 | kokopo
# Processing Record 44 of Set 4 | balkanabat
# Processing Record 45 of Set 4 | yuancheng
# Processing Record 46 of Set 4 | viedma
# Processing Record 47 of Set 4 | vrangel
# Processing Record 48 of Set 4 | superior
# Processing Record 49 of Set 4 | nabire
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | saint-joseph
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | saqqez
# Processing Record 5 of Set 5 | villarrica
# Processing Record 6 of Set 5 | atbasar
# Processing Record 7 of Set 5 | zyryanka
# Processing Record 8 of Set 5 | saint-francois
# Processing Record 9 of Set 5 | kruisfontein
# Processing Record 10 of Set 5 | porto novo
# Processing Record 11 of Set 5 | mantua
# Processing Record 12 of Set 5 | tezu
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | ganzhou
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | wittmund
# Processing Record 17 of Set 5 | avarua
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | lake havasu city
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | tasiilaq
# Processing Record 22 of Set 5 | rawatbhata
# Processing Record 23 of Set 5 | tabou
# Processing Record 24 of Set 5 | galle
# Processing Record 25 of Set 5 | sergeyevka
# Processing Record 26 of Set 5 | hofn
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 5 | grand-lahou
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | svetlaya
# Processing Record 33 of Set 5 | mweka
# Processing Record 34 of Set 5 | kahului
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | kushiro
# Processing Record 39 of Set 5 | bilibino
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | baculin
# Processing Record 42 of Set 5 | geraldton
# Processing Record 43 of Set 5 | port hedland
# Processing Record 44 of Set 5 | port alfred
# Processing Record 45 of Set 5 | naze
# Processing Record 46 of Set 5 | ambilobe
# Processing Record 47 of Set 5 | nchelenge
# Processing Record 48 of Set 5 | hirtshals
# Processing Record 49 of Set 5 | ejura
# Processing Record 50 of Set 5 | freeport
# Processing Record 1 of Set 6 | urusha
# Processing Record 2 of Set 6 | qasigiannguit
# Processing Record 3 of Set 6 | rizhao
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | alexandria
# Processing Record 6 of Set 6 | fairbanks
# Processing Record 7 of Set 6 | opunake
# Processing Record 8 of Set 6 | stanilesti
# Processing Record 9 of Set 6 | shimoda
# Processing Record 10 of Set 6 | sydney
# Processing Record 11 of Set 6 | imbituba
# Processing Record 12 of Set 6 | tessalit
# Processing Record 13 of Set 6 | pochutla
# Processing Record 14 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 15 of Set 6 | moscow
# Processing Record 16 of Set 6 | lucapa
# Processing Record 17 of Set 6 | mulege
# Processing Record 18 of Set 6 | pierre
# Processing Record 19 of Set 6 | leningradskiy
# Processing Record 20 of Set 6 | makakilo city
# Processing Record 21 of Set 6 | laem sing
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | tomatlan
# Processing Record 24 of Set 6 | okhotsk
# Processing Record 25 of Set 6 | lavrentiya
# Processing Record 26 of Set 6 | jining
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | yeppoon
# Processing Record 29 of Set 6 | poum
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | aldan
# Processing Record 32 of Set 6 | asyut
# Processing Record 33 of Set 6 | bambous virieux
# Processing Record 34 of Set 6 | maumere
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | boa vista
# Processing Record 37 of Set 6 | muros
# Processing Record 38 of Set 6 | jaristea
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | perbaungan
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | xuddur
# Processing Record 43 of Set 6 | chokurdakh
# Processing Record 44 of Set 6 | conceicao do araguaia
# Processing Record 45 of Set 6 | motril
# Processing Record 46 of Set 6 | bethel
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | lompoc
# Processing Record 49 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 50 of Set 6 | padang
# Processing Record 1 of Set 7 | lorengau
# Processing Record 2 of Set 7 | kilinochchi
# Processing Record 3 of Set 7 | acapulco
# Processing Record 4 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 5 of Set 7 | airai
# Processing Record 6 of Set 7 | husavik
# Processing Record 7 of Set 7 | cooma
# Processing Record 8 of Set 7 | nagapattinam
# Processing Record 9 of Set 7 | jimeta
# Processing Record 10 of Set 7 | aykhal
# Processing Record 11 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 12 of Set 7 | maragogi
# Processing Record 13 of Set 7 | san marcos
# Processing Record 14 of Set 7 | beira
# Processing Record 15 of Set 7 | hilo
# Processing Record 16 of Set 7 | santa isabel do rio negro
# Processing Record 17 of Set 7 | logan
# Processing Record 18 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 7 | dryden
# Processing Record 20 of Set 7 | duku
# Processing Record 21 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 7 | kyra
# Processing Record 23 of Set 7 | saint-leu
# Processing Record 24 of Set 7 | te anau
# Processing Record 25 of Set 7 | muli
# Processing Record 26 of Set 7 | ixtapa
# Processing Record 27 of Set 7 | chirilagua
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | lashio
# Processing Record 31 of Set 7 | artigas
# Processing Record 32 of Set 7 | jacareacanga
# Processing Record 33 of Set 7 | tual
# Processing Record 34 of Set 7 | sayyan
# Processing Record 35 of Set 7 | campbell river
# Processing Record 36 of Set 7 | nandaime
# Processing Record 37 of Set 7 | roald
# Processing Record 38 of Set 7 | yerbogachen
# Processing Record 39 of Set 7 | batouri
# Processing Record 40 of Set 7 | rusera
# Processing Record 41 of Set 7 | batagay
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | anadyr
# Processing Record 44 of Set 7 | cartagena del chaira
# Processing Record 45 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 7 | florianopolis
# Processing Record 47 of Set 7 | donskoye
# Processing Record 48 of Set 7 | pundaguitan
# Processing Record 49 of Set 7 | kitimat
# Processing Record 50 of Set 7 | sept-iles
# Processing Record 1 of Set 8 | zapolyarnyy
# Processing Record 2 of Set 8 | aripuana
# Processing Record 3 of Set 8 | bandarbeyla
# Processing Record 4 of Set 8 | rawson
# Processing Record 5 of Set 8 | meiganga
# Processing Record 6 of Set 8 | fujin
# Processing Record 7 of Set 8 | asgabat
# Processing Record 8 of Set 8 | maceio
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | linhares
# Processing Record 11 of Set 8 | ilhabela
# Processing Record 12 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 8 | havelock
# Processing Record 14 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 15 of Set 8 | hillsboro
# Processing Record 16 of Set 8 | jiazi
# Processing Record 17 of Set 8 | kitgum
# Processing Record 18 of Set 8 | rafai
# Processing Record 19 of Set 8 | humboldt
# Processing Record 20 of Set 8 | anchorage
# Processing Record 21 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 8 | murdochville
# Processing Record 23 of Set 8 | chuy
# Processing Record 24 of Set 8 | broken hill
# Processing Record 25 of Set 8 | port macquarie
# Processing Record 26 of Set 8 | licheng
# Processing Record 27 of Set 8 | faya
# Processing Record 28 of Set 8 | vanavara
# Processing Record 29 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | nicolas bravo
# Processing Record 32 of Set 8 | hasaki
# Processing Record 33 of Set 8 | konakovo
# Processing Record 34 of Set 8 | tautira
# Processing Record 35 of Set 8 | jatiroto
# Processing Record 36 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 8 | luanda
# Processing Record 38 of Set 8 | cairns
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 8 | nurota
# Processing Record 42 of Set 8 | lulea
# Processing Record 43 of Set 8 | mackay
# Processing Record 44 of Set 8 | hosangadi
# Processing Record 45 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 8 | tarko-sale
# Processing Record 47 of Set 8 | luganville
# Processing Record 48 of Set 8 | batagay-alyta
# Processing Record 49 of Set 8 | aanekoski
# Processing Record 50 of Set 8 | bondoukou
# Processing Record 1 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 9 | rocha
# Processing Record 3 of Set 9 | suruc
# Processing Record 4 of Set 9 | kawai
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | katobu
# Processing Record 7 of Set 9 | faanui
# Processing Record 8 of Set 9 | andrews
# Processing Record 9 of Set 9 | balikpapan
# Processing Record 10 of Set 9 | veraval
# Processing Record 11 of Set 9 | sun city west
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | jacqueville
# Processing Record 14 of Set 9 | afyonkarahisar
# Processing Record 15 of Set 9 | mogok
# Processing Record 16 of Set 9 | bereda
# Processing Record 17 of Set 9 | nemetker
# Processing Record 18 of Set 9 | sao miguel
# Processing Record 19 of Set 9 | lagoa
# Processing Record 20 of Set 9 | vestmannaeyjar
# Processing Record 21 of Set 9 | taman
# Processing Record 22 of Set 9 | vila franca do campo
# Processing Record 23 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 9 | malmesbury
# Processing Record 26 of Set 9 | pallasovka
# Processing Record 27 of Set 9 | emerald
# Processing Record 28 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 9 | baruun-urt
# Processing Record 30 of Set 9 | narsaq
# Processing Record 31 of Set 9 | iberia
# Processing Record 32 of Set 9 | bongandanga
# Processing Record 33 of Set 9 | cloquet
# Processing Record 34 of Set 9 | usinsk
# Processing Record 35 of Set 9 | tiarei
# Processing Record 36 of Set 9 | alta floresta
# Processing Record 37 of Set 9 | kochi
# Processing Record 38 of Set 9 | viljoenskroon
# Processing Record 39 of Set 9 | wolomin
# Processing Record 40 of Set 9 | luwuk
# Processing Record 41 of Set 9 | novoagansk
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | luau
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | corozal
# Processing Record 46 of Set 9 | egvekinot
# Processing Record 47 of Set 9 | douglas
# Processing Record 48 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 9 | kokoda
# Processing Record 1 of Set 10 | perelyub
# Processing Record 2 of Set 10 | merauke
# Processing Record 3 of Set 10 | uaua
# Processing Record 4 of Set 10 | cortez
# Processing Record 5 of Set 10 | peace river
# Processing Record 6 of Set 10 | hohhot
# Processing Record 7 of Set 10 | tupik
# Processing Record 8 of Set 10 | alakurtti
# Processing Record 9 of Set 10 | donghai
# Processing Record 10 of Set 10 | san juan
# Processing Record 11 of Set 10 | valdivia
# Processing Record 12 of Set 10 | sao luis
# Processing Record 13 of Set 10 | chandler
# Processing Record 14 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 10 | mbeya
# Processing Record 16 of Set 10 | vanimo
# Processing Record 17 of Set 10 | linda
# Processing Record 18 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | guilin
# Processing Record 20 of Set 10 | aksu
# Processing Record 21 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 22 of Set 10 | camacha
# Processing Record 23 of Set 10 | vulcan
# Processing Record 24 of Set 10 | logansport
# Processing Record 25 of Set 10 | betsiamites
# Processing Record 26 of Set 10 | kirakira
# Processing Record 27 of Set 10 | reconquista
# Processing Record 28 of Set 10 | lodja
# Processing Record 29 of Set 10 | wonthaggi
# Processing Record 30 of Set 10 | brigantine
# Processing Record 31 of Set 10 | brae
# Processing Record 32 of Set 10 | daru
# Processing Record 33 of Set 10 | palasa
# Processing Record 34 of Set 10 | plouzane
# Processing Record 35 of Set 10 | dayong
# Processing Record 36 of Set 10 | morant bay
# Processing Record 37 of Set 10 | najran
# Processing Record 38 of Set 10 | beringovskiy
# Processing Record 39 of Set 10 | darhan
# Processing Record 40 of Set 10 | klaksvik
# Processing Record 41 of Set 10 | buala
# Processing Record 42 of Set 10 | broome
# Processing Record 43 of Set 10 | namatanai
# Processing Record 44 of Set 10 | vestmanna
# Processing Record 45 of Set 10 | fonte boa
# Processing Record 46 of Set 10 | fort saint james
# Processing Record 47 of Set 10 | umm lajj
# Processing Record 48 of Set 10 | general pico
# Processing Record 49 of Set 10 | centralia
# Processing Record 50 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 11 | boras
# Processing Record 2 of Set 11 | almaznyy
# Processing Record 3 of Set 11 | bugama
# Processing Record 4 of Set 11 | imatra
# Processing Record 5 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 11 | raymond terrace
# Processing Record 7 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 11 | jizan
# Processing Record 9 of Set 11 | martinsburg
# Processing Record 10 of Set 11 | yelizovo
# Processing Record 11 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 11 | camaqua
# Processing Record 14 of Set 11 | coquimbo
# Processing Record 15 of Set 11 | noumea
# Processing Record 16 of Set 11 | marawi
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | stolin
# Processing Record 19 of Set 11 | saldanha
# Processing Record 20 of Set 11 | yarega
# Processing Record 21 of Set 11 | matara
# Processing Record 22 of Set 11 | bemidji
# Processing Record 23 of Set 11 | islamkot
# Processing Record 24 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 11 | panzhihua
# Processing Record 26 of Set 11 | nikolayevskaya
# Processing Record 27 of Set 11 | teya
# Processing Record 28 of Set 11 | omboue
# Processing Record 29 of Set 11 | turkistan
# Processing Record 30 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 31 of Set 11 | xichang
# Processing Record 32 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 11 | jijiga
# Processing Record 34 of Set 11 | iquique
# Processing Record 35 of Set 11 | praia da vitoria
# Processing Record 36 of Set 11 | ust-tsilma
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | buin
# Processing Record 39 of Set 11 | san jose
# Processing Record 40 of Set 11 | waipawa
# Processing Record 41 of Set 11 | cobija
# Processing Record 42 of Set 11 | sola
# Processing Record 43 of Set 11 | russell
# Processing Record 44 of Set 11 | khandyga
# Processing Record 45 of Set 11 | mosquera
# Processing Record 46 of Set 11 | palembang
# Processing Record 47 of Set 11 | santa lucia
# Processing Record 48 of Set 11 | lixourion
# Processing Record 49 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | karema
# Processing Record 1 of Set 12 | apsheronsk
# Processing Record 2 of Set 12 | medvezhyegorsk
# Processing Record 3 of Set 12 | mangai
# Processing Record 4 of Set 12 | maxixe
# Processing Record 5 of Set 12 | tura
# Processing Record 6 of Set 12 | sherbakul
# Processing Record 7 of Set 12 | melfort
# Processing Record 8 of Set 12 | kijang
# Processing Record 9 of Set 12 | abu dhabi
# Processing Record 10 of Set 12 | moramanga
# Processing Record 11 of Set 12 | thinadhoo
# Processing Record 12 of Set 12 | callaway
# Processing Record 13 of Set 12 | puerto baquerizo moreno
# Processing Record 14 of Set 12 | ust-maya
# Processing Record 15 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 12 | tongling
# Processing Record 17 of Set 12 | zeven
# Processing Record 18 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 12 | pangai
# Processing Record 21 of Set 12 | kryve ozero
# Processing Record 22 of Set 12 | narragansett
# Processing Record 23 of Set 12 | bet shemesh
# Processing Record 24 of Set 12 | port-cartier
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | phichit
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | chuka
# Processing Record 29 of Set 12 | progreso
# Processing Record 30 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 12 | jiaocheng
# Processing Record 32 of Set 12 | dickinson
# Processing Record 33 of Set 12 | kulhudhuffushi
# Processing Record 34 of Set 12 | kassala
# Processing Record 35 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 36 of Set 12 | corner brook
# Processing Record 37 of Set 12 | odienne
# Processing Record 38 of Set 12 | muzhi
# Processing Record 39 of Set 12 | kutum
# Processing Record 40 of Set 12 | bijar
# Processing Record 41 of Set 12 | bayeux
# Processing Record 42 of Set 12 | chake chake
# Processing Record 43 of Set 12 | nuuk
# Processing Record 44 of Set 12 | salalah
# Processing Record 45 of Set 12 | asau
# Processing Record 46 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 47 of Set 12 | bone
# Processing Record 48 of Set 12 | oksfjord
# Processing Record 49 of Set 12 | sergach
# Processing Record 50 of Set 12 | kurchum
# Processing Record 1 of Set 13 | gornopravdinsk
# Processing Record 2 of Set 13 | chumphon
# Processing Record 3 of Set 13 | mayumba
# Processing Record 4 of Set 13 | ubud
# Processing Record 5 of Set 13 | uspenskoye
# Processing Record 6 of Set 13 | digby
# Processing Record 7 of Set 13 | khorinsk
# Processing Record 8 of Set 13 | belmonte
# Processing Record 9 of Set 13 | lubbecke
# Processing Record 10 of Set 13 | aborlan
# Processing Record 11 of Set 13 | cruz grande
# Processing Record 12 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 13 | mogzon
# Processing Record 14 of Set 13 | da nang
# Processing Record 15 of Set 13 | jutai
# Processing Record 16 of Set 13 | mbaiki
# Processing Record 17 of Set 13 | ndouci
# City not found. Skipping...
# Processing Record 18 of Set 13 | bay roberts
# Processing Record 19 of Set 13 | kawardha
# Processing Record 20 of Set 13 | butterworth
# Processing Record 21 of Set 13 | bayan
# Processing Record 22 of Set 13 | pringsewu
# Processing Record 23 of Set 13 | pleasanton
# Processing Record 24 of Set 13 | minab
# Processing Record 25 of Set 13 | traverse city
# Processing Record 26 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 27 of Set 13 | ulaangom
# Processing Record 28 of Set 13 | tyler
# Processing Record 29 of Set 13 | chimala
# Processing Record 30 of Set 13 | verkhnyaya inta
# Processing Record 31 of Set 13 | silifke
# Processing Record 32 of Set 13 | kysyl-syr
# Processing Record 33 of Set 13 | hobyo
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | bukama
# Processing Record 36 of Set 13 | valparaiso
# Processing Record 37 of Set 13 | bucerias
# Processing Record 38 of Set 13 | ahipara
# Processing Record 39 of Set 13 | agua verde
# Processing Record 40 of Set 13 | xiangfan
# Processing Record 41 of Set 13 | ikalamavony
# Processing Record 42 of Set 13 | sobradinho
# Processing Record 43 of Set 13 | hun
# Processing Record 44 of Set 13 | bilasipara
# Processing Record 45 of Set 13 | ludvika
# Processing Record 46 of Set 13 | dongsheng
# Processing Record 47 of Set 13 | newport
# Processing Record 48 of Set 13 | batemans bay
# Processing Record 49 of Set 13 | trairi
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | semporna
# Processing Record 2 of Set 14 | cabo san lucas
# Processing Record 3 of Set 14 | hauterive
# Processing Record 4 of Set 14 | kanniyakumari
# Processing Record 5 of Set 14 | narasannapeta
# Processing Record 6 of Set 14 | sisimiut
# Processing Record 7 of Set 14 | astana
# Processing Record 8 of Set 14 | fukue
# Processing Record 9 of Set 14 | puerto madryn
# Processing Record 10 of Set 14 | bismarck
# Processing Record 11 of Set 14 | longyearbyen
# Processing Record 12 of Set 14 | tucuma
# Processing Record 13 of Set 14 | vila velha
# Processing Record 14 of Set 14 | alyangula
# Processing Record 15 of Set 14 | yarada
# Processing Record 16 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 14 | mombasa
# Processing Record 19 of Set 14 | mikuni
# Processing Record 20 of Set 14 | iralaya
# Processing Record 21 of Set 14 | palauig
# Processing Record 22 of Set 14 | mudon
# Processing Record 23 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 14 | casino
# Processing Record 25 of Set 14 | nha trang
# Processing Record 26 of Set 14 | benguela
# Processing Record 27 of Set 14 | la victoria
# Processing Record 28 of Set 14 | la ronge
# Processing Record 29 of Set 14 | ammon
# Processing Record 30 of Set 14 | skjervoy
# Processing Record 31 of Set 14 | barstow
# Processing Record 32 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 33 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 14 | tatawin
# Processing Record 35 of Set 14 | tocopilla
# Processing Record 36 of Set 14 | kommunisticheskiy
# Processing Record 37 of Set 14 | ternate
# Processing Record 38 of Set 14 | harda
# Processing Record 39 of Set 14 | saint-donat-de-montcalm
# Processing Record 40 of Set 14 | kidal
# Processing Record 41 of Set 14 | inongo
# Processing Record 42 of Set 14 | chiriguana
# Processing Record 43 of Set 14 | kalamazoo
# Processing Record 44 of Set 14 | neuquen
# Processing Record 45 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | sistranda
# Processing Record 48 of Set 14 | kalikino
# Processing Record 49 of Set 14 | daud khel
# Processing Record 50 of Set 14 | inhapim
# Processing Record 1 of Set 15 | kieta
# Processing Record 2 of Set 15 | moron
# Processing Record 3 of Set 15 | lazaro cardenas
# Processing Record 4 of Set 15 | olga
# Processing Record 5 of Set 15 | puerto del rosario
# Processing Record 6 of Set 15 | anloga
# Processing Record 7 of Set 15 | grao mogol
# Processing Record 8 of Set 15 | kasamwa
# Processing Record 9 of Set 15 | vardo
# Processing Record 10 of Set 15 | umm kaddadah
# Processing Record 11 of Set 15 | christchurch
# Processing Record 12 of Set 15 | mukdahan
# Processing Record 13 of Set 15 | macas
# Processing Record 14 of Set 15 | vila
# Processing Record 15 of Set 15 | banda aceh
# Processing Record 16 of Set 15 | manavalakurichi
# Processing Record 17 of Set 15 | klyavlino
# Processing Record 18 of Set 15 | north platte
# Processing Record 19 of Set 15 | jalu
# Processing Record 20 of Set 15 | sarkand
# Processing Record 21 of Set 15 | mount gambier
# Processing Record 22 of Set 15 | bhag
# Processing Record 23 of Set 15 | mopipi
# Processing Record 24 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 15 | zhob
# Processing Record 27 of Set 15 | mgandu
# Processing Record 28 of Set 15 | shingu
# Processing Record 29 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 15 | kandava
# Processing Record 31 of Set 15 | balkhash
# Processing Record 32 of Set 15 | santiago
# Processing Record 33 of Set 15 | susanville
# Processing Record 34 of Set 15 | bialystok
# Processing Record 35 of Set 15 | yar-sale
# Processing Record 36 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 15 | portland
# Processing Record 38 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 15 | tehachapi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa      US  22.0752 -159.3190     79.12        88          90
# 1       Busselton      AU -33.6500  115.3333     47.08        86           0
# 2         Qaanaaq      GL  77.4840  -69.3632     40.78        99         100
# 3    Punta Arenas      CL -53.1500  -70.9167     35.62        96         100
# 4     Provideniya      RU  64.3833 -173.3000     47.68        98         100
# 5  Saint-Philippe      RE -21.3585   55.7679     72.95        85          57
# 6         Kavieng      PG  -2.5744  150.7967     83.23        75          48
# 7          Olinda      BR  -8.0089  -34.8553     78.53        65          40
# 8         Ushuaia      AR -54.8000  -68.3000     37.06        70          20
# 9    Puerto Ayora      EC  -0.7393  -90.3518     71.56        74          93
#
#    Wind Speed Current Description
# 0       14.97          light rain
# 1        8.08           clear sky
# 2        6.40          light rain
# 3        1.25     overcast clouds
# 4        5.66     overcast clouds
# 5       18.01          light rain
# 6       16.51    scattered clouds
# 7       17.27    scattered clouds
# 8        0.00          few clouds
# 9        7.11     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
