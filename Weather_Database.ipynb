# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
# print(city_url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | rocha
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | kainantu
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | inhambane
# Processing Record 14 of Set 1 | tanjong malim
# City not found. Skipping...
# Processing Record 15 of Set 1 | nanortalik
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | buta
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | huron
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | hvide sande
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | buala
# Processing Record 31 of Set 1 | olafsvik
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | kashan
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | caloundra
# Processing Record 36 of Set 1 | adrar
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | iquitos
# Processing Record 40 of Set 1 | mega
# Processing Record 41 of Set 1 | zhigansk
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | nenjiang
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | keflavik
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | payson
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | chumikan
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | colares
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 2 | camrose
# Processing Record 15 of Set 2 | upata
# Processing Record 16 of Set 2 | rio brilhante
# Processing Record 17 of Set 2 | goderich
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | bairiki
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | dzilam gonzalez
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | shimanovsk
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | thinadhoo
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | egvekinot
# Processing Record 30 of Set 2 | high level
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | yerbogachen
# Processing Record 34 of Set 2 | yunyang
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | tazovskiy
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | pemangkat
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | kondinskoye
# Processing Record 42 of Set 2 | san rafael
# Processing Record 43 of Set 2 | martaban
# Processing Record 44 of Set 2 | horta
# Processing Record 45 of Set 2 | billings
# Processing Record 46 of Set 2 | montlucon
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 2 | prince rupert
# Processing Record 50 of Set 2 | mount gambier
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | korbach
# Processing Record 5 of Set 3 | baglung
# Processing Record 6 of Set 3 | cortez
# Processing Record 7 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | gamba
# Processing Record 10 of Set 3 | korla
# Processing Record 11 of Set 3 | nurota
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | waiouru
# Processing Record 14 of Set 3 | sawtell
# Processing Record 15 of Set 3 | neiafu
# Processing Record 16 of Set 3 | assiniboia
# Processing Record 17 of Set 3 | mount isa
# Processing Record 18 of Set 3 | manoel urbano
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | biltine
# Processing Record 23 of Set 3 | ballina
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | sattahip
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | wismar
# Processing Record 30 of Set 3 | limoges
# Processing Record 31 of Set 3 | awjilah
# Processing Record 32 of Set 3 | vestmannaeyjar
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | vadinsk
# Processing Record 36 of Set 3 | mayskiy
# Processing Record 37 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | padang
# Processing Record 41 of Set 3 | harper
# Processing Record 42 of Set 3 | clearlake
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | naryan-mar
# Processing Record 46 of Set 3 | karwar
# Processing Record 47 of Set 3 | skibbereen
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | la ronge
# Processing Record 50 of Set 3 | lasa
# Processing Record 1 of Set 4 | suez
# Processing Record 2 of Set 4 | takoradi
# Processing Record 3 of Set 4 | vila
# Processing Record 4 of Set 4 | petatlan
# Processing Record 5 of Set 4 | vardo
# Processing Record 6 of Set 4 | saint-augustin
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | nouadhibou
# Processing Record 9 of Set 4 | saldanha
# Processing Record 10 of Set 4 | nanae
# Processing Record 11 of Set 4 | taltal
# Processing Record 12 of Set 4 | wanaka
# Processing Record 13 of Set 4 | baishishan
# Processing Record 14 of Set 4 | meulaboh
# Processing Record 15 of Set 4 | warri
# Processing Record 16 of Set 4 | chunoyar
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | bandarbeyla
# Processing Record 19 of Set 4 | wilmington
# Processing Record 20 of Set 4 | roald
# Processing Record 21 of Set 4 | turukhansk
# Processing Record 22 of Set 4 | ust-tsilma
# Processing Record 23 of Set 4 | hefei
# Processing Record 24 of Set 4 | ivaipora
# Processing Record 25 of Set 4 | mackay
# Processing Record 26 of Set 4 | beringovskiy
# Processing Record 27 of Set 4 | bokoro
# Processing Record 28 of Set 4 | makokou
# Processing Record 29 of Set 4 | takaka
# Processing Record 30 of Set 4 | ninghai
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | havoysund
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | chegdomyn
# Processing Record 35 of Set 4 | parker
# Processing Record 36 of Set 4 | cape town
# Processing Record 37 of Set 4 | cervo
# Processing Record 38 of Set 4 | katha
# City not found. Skipping...
# Processing Record 39 of Set 4 | fuyu
# Processing Record 40 of Set 4 | biak
# Processing Record 41 of Set 4 | chilca
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | sakaiminato
# Processing Record 44 of Set 4 | pulandian
# Processing Record 45 of Set 4 | evensk
# Processing Record 46 of Set 4 | ilo
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | coihaique
# Processing Record 49 of Set 4 | davila
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | hay river
# Processing Record 2 of Set 5 | rafsanjan
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | port hedland
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | havre-saint-pierre
# Processing Record 9 of Set 5 | pangnirtung
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | outjo
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | deloraine
# Processing Record 17 of Set 5 | hithadhoo
# Processing Record 18 of Set 5 | bulgan
# Processing Record 19 of Set 5 | tamworth
# Processing Record 20 of Set 5 | paamiut
# Processing Record 21 of Set 5 | leninsk
# Processing Record 22 of Set 5 | asfi
# Processing Record 23 of Set 5 | pokanayevka
# City not found. Skipping...
# Processing Record 24 of Set 5 | arinos
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | doka
# Processing Record 27 of Set 5 | uvinza
# Processing Record 28 of Set 5 | longyearbyen
# Processing Record 29 of Set 5 | umm kaddadah
# Processing Record 30 of Set 5 | kiunga
# Processing Record 31 of Set 5 | campoverde
# Processing Record 32 of Set 5 | kuala terengganu
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | praya
# Processing Record 35 of Set 5 | rumford
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | polignano a mare
# Processing Record 38 of Set 5 | kapit
# Processing Record 39 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 5 | arucas
# Processing Record 41 of Set 5 | agde
# Processing Record 42 of Set 5 | mehamn
# Processing Record 43 of Set 5 | akyab
# Processing Record 44 of Set 5 | saint anthony
# Processing Record 45 of Set 5 | seddon
# Processing Record 46 of Set 5 | miedzychod
# Processing Record 47 of Set 5 | antalaha
# Processing Record 48 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 5 | maceio
# Processing Record 1 of Set 6 | atar
# Processing Record 2 of Set 6 | bilibino
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | kismayo
# Processing Record 5 of Set 6 | valkeakoski
# Processing Record 6 of Set 6 | honiara
# Processing Record 7 of Set 6 | nanakuli
# Processing Record 8 of Set 6 | thomastown
# Processing Record 9 of Set 6 | luwuk
# Processing Record 10 of Set 6 | hami
# Processing Record 11 of Set 6 | turayf
# Processing Record 12 of Set 6 | siirt
# Processing Record 13 of Set 6 | marzuq
# Processing Record 14 of Set 6 | hendersonville
# Processing Record 15 of Set 6 | garden city
# Processing Record 16 of Set 6 | mitsamiouli
# Processing Record 17 of Set 6 | itagiba
# Processing Record 18 of Set 6 | tyristrand
# Processing Record 19 of Set 6 | kamaishi
# Processing Record 20 of Set 6 | sovetskiy
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | portland
# Processing Record 23 of Set 6 | bethel
# Processing Record 24 of Set 6 | aswan
# Processing Record 25 of Set 6 | kallithea
# Processing Record 26 of Set 6 | pidhaytsi
# Processing Record 27 of Set 6 | trinidad
# Processing Record 28 of Set 6 | santa vitoria do palmar
# Processing Record 29 of Set 6 | dwarka
# Processing Record 30 of Set 6 | hurghada
# Processing Record 31 of Set 6 | lata
# Processing Record 32 of Set 6 | sembe
# Processing Record 33 of Set 6 | batagay-alyta
# Processing Record 34 of Set 6 | iztapa
# Processing Record 35 of Set 6 | kem
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 6 | changping
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | lichtenburg
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | ishigaki
# Processing Record 43 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 6 | rawson
# Processing Record 45 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 6 | brokopondo
# Processing Record 47 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 6 | caravelas
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | strathmore
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | ila
# Processing Record 3 of Set 7 | denizli
# Processing Record 4 of Set 7 | narasannapeta
# Processing Record 5 of Set 7 | carballo
# Processing Record 6 of Set 7 | pangkalanbuun
# Processing Record 7 of Set 7 | aykhal
# Processing Record 8 of Set 7 | le vauclin
# Processing Record 9 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 7 | raub
# Processing Record 11 of Set 7 | broome
# Processing Record 12 of Set 7 | la primavera
# Processing Record 13 of Set 7 | visby
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | vilhena
# Processing Record 16 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 7 | slidell
# Processing Record 18 of Set 7 | cabo san lucas
# Processing Record 19 of Set 7 | sao joao da barra
# Processing Record 20 of Set 7 | kutum
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | valence
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | ahuimanu
# Processing Record 26 of Set 7 | corpus christi
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | thunder bay
# Processing Record 29 of Set 7 | hlotse
# Processing Record 30 of Set 7 | pouembout
# Processing Record 31 of Set 7 | ponta delgada
# Processing Record 32 of Set 7 | eureka
# Processing Record 33 of Set 7 | zaysan
# Processing Record 34 of Set 7 | carutapera
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | sarakhs
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | ternate
# Processing Record 39 of Set 7 | gat
# Processing Record 40 of Set 7 | dubai
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | mariinsk
# Processing Record 43 of Set 7 | lira
# Processing Record 44 of Set 7 | east london
# Processing Record 45 of Set 7 | beyla
# Processing Record 46 of Set 7 | faya
# Processing Record 47 of Set 7 | salalah
# Processing Record 48 of Set 7 | tatawin
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | panguipulli
# Processing Record 1 of Set 8 | susanville
# Processing Record 2 of Set 8 | sapulpa
# Processing Record 3 of Set 8 | savelugu
# Processing Record 4 of Set 8 | inuvik
# Processing Record 5 of Set 8 | pariquera-acu
# City not found. Skipping...
# Processing Record 6 of Set 8 | acarau
# Processing Record 7 of Set 8 | pochutla
# Processing Record 8 of Set 8 | lagoa
# Processing Record 9 of Set 8 | richmond
# Processing Record 10 of Set 8 | port lincoln
# Processing Record 11 of Set 8 | port-gentil
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | paragould
# Processing Record 14 of Set 8 | trelleborg
# Processing Record 15 of Set 8 | tazmalt
# Processing Record 16 of Set 8 | klaksvik
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | anloga
# Processing Record 19 of Set 8 | dzaoudzi
# Processing Record 20 of Set 8 | shaoguan
# Processing Record 21 of Set 8 | muros
# Processing Record 22 of Set 8 | longyan
# Processing Record 23 of Set 8 | coahuayana
# Processing Record 24 of Set 8 | dangtu
# Processing Record 25 of Set 8 | douentza
# Processing Record 26 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 27 of Set 8 | kaitangata
# Processing Record 28 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 29 of Set 8 | chifeng
# Processing Record 30 of Set 8 | viransehir
# Processing Record 31 of Set 8 | belogorsk
# Processing Record 32 of Set 8 | balabac
# Processing Record 33 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 34 of Set 8 | mahebourg
# Processing Record 35 of Set 8 | challakere
# Processing Record 36 of Set 8 | san policarpo
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | kaputa
# Processing Record 39 of Set 8 | macas
# Processing Record 40 of Set 8 | koumac
# Processing Record 41 of Set 8 | naze
# Processing Record 42 of Set 8 | zapolyarnyy
# Processing Record 43 of Set 8 | antofagasta
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | marawi
# Processing Record 46 of Set 8 | baturaja
# Processing Record 47 of Set 8 | yangcun
# Processing Record 48 of Set 8 | olkhovka
# Processing Record 49 of Set 8 | churapcha
# Processing Record 50 of Set 8 | bari sadri
# Processing Record 1 of Set 9 | quesnel
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | salym
# Processing Record 4 of Set 9 | lagos
# Processing Record 5 of Set 9 | tlahuapan
# City not found. Skipping...
# Processing Record 6 of Set 9 | waingapu
# Processing Record 7 of Set 9 | yerofey pavlovich
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | bilma
# Processing Record 12 of Set 9 | port elizabeth
# Processing Record 13 of Set 9 | bonthe
# Processing Record 14 of Set 9 | jiuquan
# Processing Record 15 of Set 9 | sulangan
# Processing Record 16 of Set 9 | karaton
# Processing Record 17 of Set 9 | santa lucia
# Processing Record 18 of Set 9 | kawalu
# Processing Record 19 of Set 9 | mangrol
# Processing Record 20 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 9 | zmeinogorsk
# Processing Record 23 of Set 9 | pozo de gamboa
# City not found. Skipping...
# Processing Record 24 of Set 9 | lakes entrance
# Processing Record 25 of Set 9 | baracoa
# Processing Record 26 of Set 9 | tela
# Processing Record 27 of Set 9 | margate
# Processing Record 28 of Set 9 | baykit
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | le port
# Processing Record 31 of Set 9 | mapiripan
# Processing Record 32 of Set 9 | onega
# Processing Record 33 of Set 9 | aitape
# Processing Record 34 of Set 9 | sabang
# Processing Record 35 of Set 9 | humaita
# Processing Record 36 of Set 9 | nuevo ideal
# Processing Record 37 of Set 9 | dali
# Processing Record 38 of Set 9 | maarianhamina
# Processing Record 39 of Set 9 | zhuhai
# Processing Record 40 of Set 9 | atbasar
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | birao
# Processing Record 43 of Set 9 | noumea
# Processing Record 44 of Set 9 | broken hill
# Processing Record 45 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 9 | wrexham
# Processing Record 47 of Set 9 | santa maria
# Processing Record 48 of Set 9 | hirara
# Processing Record 49 of Set 9 | san jose de gracia
# Processing Record 50 of Set 9 | aygedzor
# Processing Record 1 of Set 10 | anito
# Processing Record 2 of Set 10 | mahibadhoo
# Processing Record 3 of Set 10 | carmen
# Processing Record 4 of Set 10 | pisco
# Processing Record 5 of Set 10 | roma
# Processing Record 6 of Set 10 | coronel vivida
# Processing Record 7 of Set 10 | teahupoo
# Processing Record 8 of Set 10 | myaundzha
# Processing Record 9 of Set 10 | salgado de sao felix
# Processing Record 10 of Set 10 | brentwood
# Processing Record 11 of Set 10 | sigli
# Processing Record 12 of Set 10 | trabzon
# Processing Record 13 of Set 10 | banjar
# Processing Record 14 of Set 10 | coos bay
# Processing Record 15 of Set 10 | doliana
# Processing Record 16 of Set 10 | mokrous
# Processing Record 17 of Set 10 | sorong
# Processing Record 18 of Set 10 | los llanos de aridane
# Processing Record 19 of Set 10 | puerto colombia
# Processing Record 20 of Set 10 | arman
# Processing Record 21 of Set 10 | yenagoa
# Processing Record 22 of Set 10 | ola
# Processing Record 23 of Set 10 | soma
# Processing Record 24 of Set 10 | bayonne
# Processing Record 25 of Set 10 | chiang klang
# Processing Record 26 of Set 10 | ossora
# Processing Record 27 of Set 10 | samarai
# Processing Record 28 of Set 10 | alcaniz
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | gravdal
# Processing Record 31 of Set 10 | ugoofaaru
# Processing Record 32 of Set 10 | saint-pierre
# Processing Record 33 of Set 10 | clyde river
# Processing Record 34 of Set 10 | puerto leguizamo
# Processing Record 35 of Set 10 | barra do corda
# Processing Record 36 of Set 10 | san vicente
# Processing Record 37 of Set 10 | salme
# Processing Record 38 of Set 10 | puga
# Processing Record 39 of Set 10 | bambanglipuro
# Processing Record 40 of Set 10 | los amates
# Processing Record 41 of Set 10 | kindu
# Processing Record 42 of Set 10 | wageningen
# Processing Record 43 of Set 10 | corn island
# Processing Record 44 of Set 10 | mae ramat
# Processing Record 45 of Set 10 | pilar
# Processing Record 46 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 10 | grindavik
# Processing Record 48 of Set 10 | tocopilla
# Processing Record 49 of Set 10 | maniwaki
# Processing Record 50 of Set 10 | brigantine
# Processing Record 1 of Set 11 | rajpura
# Processing Record 2 of Set 11 | pacific grove
# Processing Record 3 of Set 11 | hawalli
# Processing Record 4 of Set 11 | monterey
# Processing Record 5 of Set 11 | qiyang
# Processing Record 6 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 11 | lavrentiya
# Processing Record 8 of Set 11 | glendive
# Processing Record 9 of Set 11 | palafrugell
# Processing Record 10 of Set 11 | ust-karsk
# Processing Record 11 of Set 11 | la maddalena
# Processing Record 12 of Set 11 | nantucket
# Processing Record 13 of Set 11 | juneau
# Processing Record 14 of Set 11 | pangai
# Processing Record 15 of Set 11 | phra phutthabat
# Processing Record 16 of Set 11 | boa vista
# Processing Record 17 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 11 | piacabucu
# Processing Record 19 of Set 11 | tabou
# Processing Record 20 of Set 11 | sinnamary
# Processing Record 21 of Set 11 | puerto madryn
# Processing Record 22 of Set 11 | san francisco
# Processing Record 23 of Set 11 | kalianget
# Processing Record 24 of Set 11 | veraval
# Processing Record 25 of Set 11 | luorong
# Processing Record 26 of Set 11 | ajdabiya
# Processing Record 27 of Set 11 | verkhnyaya inta
# Processing Record 28 of Set 11 | huilong
# Processing Record 29 of Set 11 | lompoc
# Processing Record 30 of Set 11 | belen
# Processing Record 31 of Set 11 | rawlins
# Processing Record 32 of Set 11 | panama city
# Processing Record 33 of Set 11 | atasu
# Processing Record 34 of Set 11 | sakakah
# Processing Record 35 of Set 11 | kuching
# Processing Record 36 of Set 11 | banganapalle
# Processing Record 37 of Set 11 | kalaleh
# Processing Record 38 of Set 11 | isla mujeres
# Processing Record 39 of Set 11 | sayyan
# Processing Record 40 of Set 11 | pimenta bueno
# Processing Record 41 of Set 11 | sao jose da coroa grande
# Processing Record 42 of Set 11 | drovyanaya
# Processing Record 43 of Set 11 | veere
# Processing Record 44 of Set 11 | perivolion
# Processing Record 45 of Set 11 | leua
# Processing Record 46 of Set 11 | aklavik
# Processing Record 47 of Set 11 | boyolangu
# Processing Record 48 of Set 11 | chongwe
# Processing Record 49 of Set 11 | bontang
# Processing Record 50 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 12 | mercedes
# Processing Record 2 of Set 12 | alyangula
# Processing Record 3 of Set 12 | buchanan
# Processing Record 4 of Set 12 | mirandopolis
# Processing Record 5 of Set 12 | kortkeros
# Processing Record 6 of Set 12 | hvolsvollur
# Processing Record 7 of Set 12 | axim
# Processing Record 8 of Set 12 | narrabri
# Processing Record 9 of Set 12 | polovinnoye
# Processing Record 10 of Set 12 | comarapa
# Processing Record 11 of Set 12 | ko samui
# Processing Record 12 of Set 12 | solnechnyy
# Processing Record 13 of Set 12 | waipawa
# Processing Record 14 of Set 12 | toora-khem
# Processing Record 15 of Set 12 | vilyuysk
# Processing Record 16 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 12 | idanre
# Processing Record 18 of Set 12 | port keats
# Processing Record 19 of Set 12 | saint george
# Processing Record 20 of Set 12 | sosnovo-ozerskoye
# Processing Record 21 of Set 12 | de-kastri
# Processing Record 22 of Set 12 | igrim
# Processing Record 23 of Set 12 | dukat
# Processing Record 24 of Set 12 | damaturu
# Processing Record 25 of Set 12 | okahandja
# Processing Record 26 of Set 12 | trairi
# Processing Record 27 of Set 12 | raga
# Processing Record 28 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | kavaratti
# Processing Record 30 of Set 12 | mattru
# Processing Record 31 of Set 12 | aksakovo
# Processing Record 32 of Set 12 | leh
# Processing Record 33 of Set 12 | rincon
# Processing Record 34 of Set 12 | storforshei
# Processing Record 35 of Set 12 | saint-joseph
# Processing Record 36 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | merauke
# Processing Record 39 of Set 12 | trapani
# Processing Record 40 of Set 12 | victor harbor
# Processing Record 41 of Set 12 | lewistown
# Processing Record 42 of Set 12 | agirish
# Processing Record 43 of Set 12 | gimli
# Processing Record 44 of Set 12 | miraflores
# Processing Record 45 of Set 12 | kodinsk
# Processing Record 46 of Set 12 | dudinka
# Processing Record 47 of Set 12 | sopelana
# Processing Record 48 of Set 12 | amapa
# Processing Record 49 of Set 12 | tucurui
# Processing Record 50 of Set 12 | caucaia
# Processing Record 1 of Set 13 | mezhova
# Processing Record 2 of Set 13 | jalingo
# Processing Record 3 of Set 13 | nosy varika
# Processing Record 4 of Set 13 | batagay
# Processing Record 5 of Set 13 | lahij
# Processing Record 6 of Set 13 | kaeo
# Processing Record 7 of Set 13 | balykshi
# Processing Record 8 of Set 13 | wurzburg
# Processing Record 9 of Set 13 | ulladulla
# Processing Record 10 of Set 13 | zhob
# Processing Record 11 of Set 13 | ilulissat
# Processing Record 12 of Set 13 | lima
# Processing Record 13 of Set 13 | vanavara
# Processing Record 14 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 13 | angoche
# Processing Record 16 of Set 13 | kirensk
# Processing Record 17 of Set 13 | port blair
# Processing Record 18 of Set 13 | isangel
# Processing Record 19 of Set 13 | sitka
# Processing Record 20 of Set 13 | impfondo
# Processing Record 21 of Set 13 | aasiaat
# Processing Record 22 of Set 13 | panaba
# Processing Record 23 of Set 13 | presidencia roque saenz pena
# Processing Record 24 of Set 13 | cayenne
# Processing Record 25 of Set 13 | shimoda
# Processing Record 26 of Set 13 | zheleznodorozhnyy
# Processing Record 27 of Set 13 | port shepstone
# Processing Record 28 of Set 13 | da nang
# Processing Record 29 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 30 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 31 of Set 13 | mbekenyera
# Processing Record 32 of Set 13 | worthington
# Processing Record 33 of Set 13 | praia da vitoria
# Processing Record 34 of Set 13 | luau
# Processing Record 35 of Set 13 | wenling
# Processing Record 36 of Set 13 | halifax
# Processing Record 37 of Set 13 | lawrence
# Processing Record 38 of Set 13 | sovetskaya gavan
# Processing Record 39 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 40 of Set 13 | chimoio
# Processing Record 41 of Set 13 | suntar
# Processing Record 42 of Set 13 | pangoa
# Processing Record 43 of Set 13 | langfang
# Processing Record 44 of Set 13 | yima
# Processing Record 45 of Set 13 | havelock
# Processing Record 46 of Set 13 | wajima
# Processing Record 47 of Set 13 | nova olinda do norte
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | buraydah
# Processing Record 50 of Set 13 | mayumba
# Processing Record 1 of Set 14 | irbeyskoye
# Processing Record 2 of Set 14 | ambon
# Processing Record 3 of Set 14 | ordu
# Processing Record 4 of Set 14 | sobolevo
# Processing Record 5 of Set 14 | weligama
# Processing Record 6 of Set 14 | kasongo-lunda
# Processing Record 7 of Set 14 | bangkal
# Processing Record 8 of Set 14 | baie-comeau
# Processing Record 9 of Set 14 | zalantun
# Processing Record 10 of Set 14 | seredka
# Processing Record 11 of Set 14 | sola
# Processing Record 12 of Set 14 | cururupu
# Processing Record 13 of Set 14 | husavik
# Processing Record 14 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | kiruna
# Processing Record 16 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 14 | pinawa
# Processing Record 18 of Set 14 | calvinia
# Processing Record 19 of Set 14 | najran
# Processing Record 20 of Set 14 | dalvik
# Processing Record 21 of Set 14 | eyl
# Processing Record 22 of Set 14 | champerico
# Processing Record 23 of Set 14 | nipawin
# Processing Record 24 of Set 14 | tutoia
# Processing Record 25 of Set 14 | viedma
# Processing Record 26 of Set 14 | dubrovnik
# Processing Record 27 of Set 14 | biloxi
# Processing Record 28 of Set 14 | manokwari
# Processing Record 29 of Set 14 | severnoye
# Processing Record 30 of Set 14 | wallaceburg
# Processing Record 31 of Set 14 | wilson
# Processing Record 32 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 33 of Set 14 | hurup
# Processing Record 34 of Set 14 | sirjan
# Processing Record 35 of Set 14 | yoichi
# Processing Record 36 of Set 14 | avera
# Processing Record 37 of Set 14 | chester-le-street
# Processing Record 38 of Set 14 | seinajoki
# Processing Record 39 of Set 14 | san buenaventura
# Processing Record 40 of Set 14 | iwanai
# Processing Record 41 of Set 14 | inyonga
# Processing Record 42 of Set 14 | fort frances
# Processing Record 43 of Set 14 | hervey bay
# Processing Record 44 of Set 14 | bud
# Processing Record 45 of Set 14 | taoudenni
# Processing Record 46 of Set 14 | rosetta
# Processing Record 47 of Set 14 | tiarei
# Processing Record 48 of Set 14 | barra do garcas
# Processing Record 49 of Set 14 | poddorye
# Processing Record 50 of Set 14 | natal
# Processing Record 1 of Set 15 | westerland
# Processing Record 2 of Set 15 | oga
# Processing Record 3 of Set 15 | krasnyy chikoy
# Processing Record 4 of Set 15 | montefiascone
# Processing Record 5 of Set 15 | civitanova marche
# Processing Record 6 of Set 15 | asgabat
# Processing Record 7 of Set 15 | ciorogarla
# Processing Record 8 of Set 15 | kaohsiung
# Processing Record 9 of Set 15 | kirakira
# Processing Record 10 of Set 15 | alice springs
# Processing Record 11 of Set 15 | jacareacanga
# Processing Record 12 of Set 15 | san luis
# Processing Record 13 of Set 15 | golden
# Processing Record 14 of Set 15 | qui nhon
# Processing Record 15 of Set 15 | chivay
# Processing Record 16 of Set 15 | camacha
# Processing Record 17 of Set 15 | mandla
# Processing Record 18 of Set 15 | zhovtneve
# Processing Record 19 of Set 15 | kidal
# Processing Record 20 of Set 15 | ariquemes
# Processing Record 21 of Set 15 | san angelo
# Processing Record 22 of Set 15 | pozzallo
# Processing Record 23 of Set 15 | peterhead
# Processing Record 24 of Set 15 | haines junction
# Processing Record 25 of Set 15 | okhotsk
# Processing Record 26 of Set 15 | chaohu
# Processing Record 27 of Set 15 | torrington
# Processing Record 28 of Set 15 | stony plain
# Processing Record 29 of Set 15 | kloulklubed
# Processing Record 30 of Set 15 | marsh harbour
# Processing Record 31 of Set 15 | sarai naurang
# Processing Record 32 of Set 15 | tahe
# Processing Record 33 of Set 15 | zhezkazgan
# Processing Record 34 of Set 15 | chunhuhub
# Processing Record 35 of Set 15 | chengdu
# Processing Record 36 of Set 15 | ken caryl
# Processing Record 37 of Set 15 | jawa
# Processing Record 38 of Set 15 | jaitaran
# Processing Record 39 of Set 15 | semnan
# Processing Record 40 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 41 of Set 15 | botou
# Processing Record 42 of Set 15 | tomatlan
# Processing Record 43 of Set 15 | raudeberg
# Processing Record 44 of Set 15 | voskresenskoye
# Processing Record 45 of Set 15 | oranjemund
# Processing Record 46 of Set 15 | malanje
# Processing Record 47 of Set 15 | khuldabad
# Processing Record 48 of Set 15 | logon
# Processing Record 49 of Set 15 | forset
# City not found. Skipping...
# Processing Record 50 of Set 15 | nelson bay
# Processing Record 1 of Set 16 | craig
# Processing Record 2 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 16 | sibolga
# Processing Record 4 of Set 16 | sidney
# Processing Record 5 of Set 16 | karasjok
# Processing Record 6 of Set 16 | chissamba
# Processing Record 7 of Set 16 | camalu
# Processing Record 8 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | troitskoye
# Processing Record 10 of Set 16 | sokoto
# Processing Record 11 of Set 16 | borogontsy
# Processing Record 12 of Set 16 | phan rang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Qaanaaq      GL  77.4840  -69.3632     41.79        71
# 1          Puerto Ayora      EC  -0.7393  -90.3518     75.16        75
# 2             Jamestown      US  42.0970  -79.2353     81.30        91
# 3                 Rocha      UY -34.4833  -54.3333     54.21        62
# 4            Codrington      AU -38.2667  141.9667     46.44        96
# 5              Kainantu      PG  -6.2887  145.8655     55.36        90
# 6             Carnarvon      AU -24.8667  113.6333     48.27        33
# 7                Atuona      PF  -9.8000 -139.0333     76.87        74
# 8  Vila Franca Do Campo      PT  37.7167  -25.4333     75.61        68
# 9                Albany      US  42.6001  -73.9662     91.80        67
#
#    Cloudiness  Wind Speed Current Description
# 0          96        3.36     overcast clouds
# 1          67        8.01       broken clouds
# 2           1        1.01           clear sky
# 3           1        4.50           clear sky
# 4          42       11.95    scattered clouds
# 5          44        1.77    scattered clouds
# 6           0        6.91           clear sky
# 7          29       18.16          light rain
# 8           2       11.25           clear sky
# 9          31        8.03    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
